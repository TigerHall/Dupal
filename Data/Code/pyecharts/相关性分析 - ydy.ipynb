# %% [markdown]
# 相关性热力图

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")  # 过滤掉警告的意思

# %%
# 数据处理

df = pd.read_csv('ydy.csv')
df.head()
# print(df)
new_df = df.corr()
print(new_df)#打印值
# Out:
#           区域ID        纬度        经度       LOC        SR        ND       PB6  \
# 区域ID  1.000000  0.828262 -0.263240 -0.024403 -0.022912  0.130786  0.219746
# 纬度    0.828262  1.000000 -0.302798 -0.085293 -0.090753  0.238107 -0.059931
# 经度   -0.263240 -0.302798  1.000000 -0.210701 -0.226420  0.088607  0.006164
# LOC  -0.024403 -0.085293 -0.210701  1.000000  0.082071 -0.104258  0.225270
# SR   -0.022912 -0.090753 -0.226420  0.082071  1.000000 -0.888498 -0.098372
# ND    0.130786  0.238107  0.088607 -0.104258 -0.888498  1.000000 -0.006128
# PB6   0.219746 -0.059931  0.006164  0.225270 -0.098372 -0.006128  1.000000
# PB7   0.142121 -0.057222 -0.202819  0.212498  0.374601 -0.381917  0.702742
# PB8   0.246233 -0.010473 -0.097787  0.182436  0.251728 -0.318009  0.894811
#
#            PB7       PB8
# 区域ID  0.142121  0.246233
# 纬度   -0.057222 -0.010473
# 经度   -0.202819 -0.097787
# LOC   0.212498  0.182436
# SR    0.374601  0.251728
# ND   -0.381917 -0.318009
# PB6   0.702742  0.894811
# ...

# %%
import holoviews as hv
from holoviews import opts

data = [(i, chr(97+j),  i*j) for i in range(5) for j in range(5) if i != j]

hm = hv.HeatMap(data).sort()
# hm.opts(xticks=None,)

# %%
# 出图设置

# 图片显示中文
plt.rcParams['font.sans-serif'] = ['SimHei']
# 正常显示符号
plt.rcParams['axes.unicode_minus'] = False

# 设置横纵坐标的名称及热力图名称以及对应字体格式
font1 = {
    'family': 'SimHei',
    'weight': 'normal',
    'size': 100,
}

# 调整画布大小
ax = plt.subplots(figsize=(60, 60), dpi=200)

# 画热力图   annot=True 表示显示系数
ax = sns.heatmap(
    new_df,
    square=True,
    annot=True,
    # 网格内数字大小
    annot_kws={"fontsize": 60}
)

# colorbar
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=60)

# 设置坐标字体大小
plt.xticks(fontsize=60)
plt.yticks(fontsize=60)

# 热力图名称
ax.set_title('印度洋洋中脊同位素相关性图', font1)

# 出图
plt.savefig('印度洋洋中脊同位素相关性.png')
